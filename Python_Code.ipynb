# %% [markdown]
# <a href="https://colab.research.google.com/github/mahossaineeejust/Python-First-Code/blob/main/Python_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
y=12
z=x+y
print(z)
# Out:
# 22

# %%
p=14
q=18
r=p-q
s=p*r
print(r,s)
# Out:
# -4 -56
